# %% [markdown]
# # EXERCICI 1

# %%
import pandas as pd
import numpy as np

#descarrega dataframe DelayedFlights

ret = pd.read_csv('DelayedFlights.csv')
ret.head(13) #mostra les 13 primeres files, per fer una criba de les columnes a triar
# Out:
#     Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0            0  2008      1           3          4   2003.0        1955
# 1            1  2008      1           3          4    754.0         735
# 2            2  2008      1           3          4    628.0         620
# 3            4  2008      1           3          4   1829.0        1755
# 4            5  2008      1           3          4   1940.0        1915
# 5            6  2008      1           3          4   1937.0        1830
# 6           10  2008      1           3          4    706.0         700
# 7           11  2008      1           3          4   1644.0        1510
# 8           15  2008      1           3          4   1029.0        1020
# 9           16  2008      1           3          4   1452.0        1425
# 10          17  2008      1           3          4    754.0         745
# 11          18  2008      1           3          4   1323.0        1255
# ...

# %%
ret.info() #info del dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1936758 entries, 0 to 1936757
# Data columns (total 30 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Unnamed: 0         int64
#  1   Year               int64
#  2   Month              int64
#  3   DayofMonth         int64
#  4   DayOfWeek          int64
#  5   DepTime            float64
#  6   CRSDepTime         int64
#  7   ArrTime            float64
#  8   CRSArrTime         int64
#  9   UniqueCarrier      object
#  10  FlightNum          int64
#  11  TailNum            object
#  12  ActualElapsedTime  float64
#  13  CRSElapsedTime     float64
#  14  AirTime            float64
#  15  ArrDelay           float64
#  16  DepDelay           float64
#  17  Origin             object
#  18  Dest               object
#  19  Distance           int64
#  20  TaxiIn             float64
#  21  TaxiOut            float64
#  22  Cancelled          int64
#  23  CancellationCode   object
# ...

# %%
ret.shape #número de files i columnes totals del dataframe
# Out:
# (1936758, 30)

# %%
ret.columns #columnes del dataframe
# Out:
# Index(['Unnamed: 0', 'Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime',
#        'CRSDepTime', 'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum',
#        'TailNum', 'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
# tria columnes necessàries

# eliminació any: valor no útil per analisi, totes les dades són del 2008.
# justificació tria mesos i dies mes i setmana: analitzar si retards es donen en mesos i/o dies mes concrets.
# justificació temps dep, arr i altres: anàlisi de minimització de retard durant el vol, o altres.
# eliminació FlightNumnúmero: valor no útil per anàlisi.
# justificació Origin, Dest, Distance: anàlisi retards i distàncies.
# eliminació TaxiIn, TaxiOut: desconeixement del valor
# justificació TailNum: anàlisi avió que acumula més retards.
# eliminació Cancelled, CancellationCode, Diverted: valors no vàlids per anàlisi de retards.
# justificació CarrierDelay, WeatherDelay, NASDelay', SecurityDelay, LateAircraftDelay: anàlisi motiu retard.


lessret = ret[['Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime', 'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'TailNum', 'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay', 'DepDelay', 'Origin', 'Dest', 'Distance', 'CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay']]
lessret
# Out:
#          Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0            1           3          4   2003.0        1955   2211.0
# 1            1           3          4    754.0         735   1002.0
# 2            1           3          4    628.0         620    804.0
# 3            1           3          4   1829.0        1755   1959.0
# 4            1           3          4   1940.0        1915   2121.0
# ...        ...         ...        ...      ...         ...      ...
# 1936753     12          13          6   1250.0        1220   1617.0
# 1936754     12          13          6    657.0         600    904.0
# 1936755     12          13          6   1007.0         847   1149.0
# 1936756     12          13          6   1251.0        1240   1446.0
# 1936757     12          13          6   1110.0        1103   1413.0
#
#          CRSArrTime UniqueCarrier TailNum  ActualElapsedTime  ...  ArrDelay  \
# ...

# %%
#triar 200000 valors aleatoriament

retard = lessret.sample(n = 200000).reset_index(drop=True) 
retard
# Out:
#         Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0           7          20          7   1441.0        1420   1753.0
# 1           8           9          6   1640.0        1610   1932.0
# 2           2          13          3   2125.0        2105   2233.0
# 3           7           7          1   2036.0        2020   2203.0
# 4          10          22          3   1448.0        1340   1845.0
# ...       ...         ...        ...      ...         ...      ...
# 199995      1           3          4   1538.0        1455   1640.0
# 199996      6           9          1   1725.0        1540    121.0
# 199997      7          25          5   1128.0         855   1328.0
# 199998      6          15          7     15.0        2230    749.0
# 199999      7          12          6   2000.0        1945   2114.0
#
#         CRSArrTime UniqueCarrier TailNum  ActualElapsedTime  ...  ArrDelay  \
# 0             1720            MQ  N621AE              132.0  ...      33.0
# ...

# %%
retard.shape
# Out:
# (200000, 22)

# %% [markdown]
# # EXERCICI 2

# %%
retard.info() #informacio del dataset retard i columnes d'interés
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 22 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Month              200000 non-null  int64
#  1   DayofMonth         200000 non-null  int64
#  2   DayOfWeek          200000 non-null  int64
#  3   DepTime            200000 non-null  float64
#  4   CRSDepTime         200000 non-null  int64
#  5   ArrTime            199253 non-null  float64
#  6   CRSArrTime         200000 non-null  int64
#  7   UniqueCarrier      200000 non-null  object
#  8   TailNum            199999 non-null  object
#  9   ActualElapsedTime  199114 non-null  float64
#  10  CRSElapsedTime     199983 non-null  float64
#  11  AirTime            199114 non-null  float64
#  12  ArrDelay           199114 non-null  float64
#  13  DepDelay           200000 non-null  float64
#  14  Origin             200000 non-null  object
# ...

# %%
retard.describe() #resum estadístic del dataset retard
# Out:
#                Month     DayofMonth      DayOfWeek        DepTime  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        6.105875      15.769845       3.978720    1518.095640
# std         3.484805       8.770951       1.997262     450.723353
# min         1.000000       1.000000       1.000000       1.000000
# 25%         3.000000       8.000000       2.000000    1202.000000
# 50%         6.000000      16.000000       4.000000    1545.000000
# 75%         9.000000      23.000000       6.000000    1900.000000
# max        12.000000      31.000000       7.000000    2400.000000
#
#           CRSDepTime        ArrTime     CRSArrTime  ActualElapsedTime  \
# count  200000.000000  199253.000000  200000.000000      199114.000000
# mean     1467.084240    1610.171691    1633.369775         133.578754
# std       424.765408     547.925886     464.917136          72.132035
# min         1.000000       1.000000       0.000000          18.000000
# ...

# %%
# resum estadístic columna retards.

retsor = retard['CRSDepTime'] #tria columna retard sortida
retsor.describe()
# Out:
# count    200000.000000
# mean       1467.084240
# std         424.765408
# min           1.000000
# 25%        1135.000000
# 50%        1510.000000
# 75%        1815.000000
# max        2359.000000
# Name: CRSDepTime, dtype: float64

# %%
# resum estadístic columna retards arribada.

retarr = retard['CRSArrTime'] #tria columna retard arribada
retarr.describe()
# Out:
# count    200000.000000
# mean       1633.369775
# std         464.917136
# min           0.000000
# 25%        1325.000000
# 50%        1705.000000
# 75%        2014.250000
# max        2400.000000
# Name: CRSArrTime, dtype: float64

# %%
# resum estadístic columna distància.

dista = retard['Distance'] #tria columna distància
dista.describe()
# Out:
# count    200000.000000
# mean        767.416900
# std         574.516657
# min          31.000000
# 25%         340.000000
# 50%         609.000000
# 75%        1003.000000
# max        4962.000000
# Name: Distance, dtype: float64

# %%
# dades faltants per columna.

retard.isnull().sum() # número de nulls per columna
# Out:
# Month                    0
# DayofMonth               0
# DayOfWeek                0
# DepTime                  0
# CRSDepTime               0
# ArrTime                742
# CRSArrTime               0
# UniqueCarrier            0
# TailNum                  1
# ActualElapsedTime      871
# CRSElapsedTime          21
# AirTime                871
# ArrDelay               871
# DepDelay                 0
# Origin                   0
# Dest                     0
# Distance                 0
# CarrierDelay         71131
# WeatherDelay         71131
# NASDelay             71131
# SecurityDelay        71131
# LateAircraftDelay    71131
# dtype: int64

# %%
#càlcul velocitat mitja

dist = retard['Distance']
vel = retard['CRSElapsedTime']
vel_mitja = dist/vel

retard['vel_m'] = vel_mitja #afegim columna al dataframe retard
retard
# Out:
#         Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0           7          20          7   1441.0        1420   1753.0
# 1           8           9          6   1640.0        1610   1932.0
# 2           2          13          3   2125.0        2105   2233.0
# 3           7           7          1   2036.0        2020   2203.0
# 4          10          22          3   1448.0        1340   1845.0
# ...       ...         ...        ...      ...         ...      ...
# 199995      1           3          4   1538.0        1455   1640.0
# 199996      6           9          1   1725.0        1540    121.0
# 199997      7          25          5   1128.0         855   1328.0
# 199998      6          15          7     15.0        2230    749.0
# 199999      7          12          6   2000.0        1945   2114.0
#
#         CRSArrTime UniqueCarrier TailNum  ActualElapsedTime  ...  DepDelay  \
# 0             1720            MQ  N621AE              132.0  ...      21.0
# ...

# %%
# vol amb retard? si/no

# nova columna

def sn(x):
    for x in retard['CRSArrTime']:
        if x == retard['ArrTime']:
            print('NO retard') in ot
        else:
            print('YES retard') in ot
            
            ot = retard['vel_m']
            retard

# NO ENTENC????

# %%
retard['UniqueCarrier'] #aerolinees del dataframe

# taula aerolinies amb més retards

comp_ret = retard['UniqueCarrier'].value_counts()
comp_ret
# Out:
# WN    39041
# AA    20006
# MQ    14513
# UA    14506
# OO    13622
# DL    12169
# XE    10587
# CO    10422
# US    10245
# EV     8597
# NW     8195
# FL     7257
# YV     6779
# B6     5645
# OH     5340
# 9E     5294
# AS     4048
# F9     2901
# HA      758
# AQ       75
# Name: UniqueCarrier, dtype: int64

# %%
#distancia més llarga

vols = retard.groupby('UniqueCarrier').count() #agrupació per vols
vols
# Out:
#                Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# UniqueCarrier
# 9E              5294        5294       5294     5294        5294     5272
# AA             20006       20006      20006    20006       20006    19921
# AQ                75          75         75       75          75       73
# AS              4048        4048       4048     4048        4048     4020
# B6              5645        5645       5645     5645        5645     5623
# CO             10422       10422      10422    10422       10422    10381
# DL             12169       12169      12169    12169       12169    12115
# EV              8597        8597       8597     8597        8597     8591
# F9              2901        2901       2901     2901        2901     2893
# FL              7257        7257       7257     7257        7257     7231
# HA               758         758        758      758         758      758
# ...

# %%
# vols mes llargs

mes_temps = retard['ActualElapsedTime']
max_temps = mes_temps.max() # màxim temps de vol
max_temps
# Out:
# 687.0

# %%
# vol més endarrerit

mes_retard = retard['ArrDelay']
max_retard = mes_retard.max() #màxim retard
max_retard
# Out:
# 1707.0

# %%
# distància més llarga

mes_dist = retard['Distance']
max_dist = mes_dist.max() #màxima distància
max_dist
# Out:
# 4962

# %% [markdown]
# # EXERCICI 3

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# dataset retard a Excel

datatoexcel = pd.ExcelWriter('Retards.xlsx')
retard.to_excel(datatoexcel)
datatoexcel.save()
